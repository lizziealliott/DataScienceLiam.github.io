# %% [markdown]
# <a href="https://colab.research.google.com/github/DataScienceLiam/DataScienceLiam.github.io/blob/main/Data_scraper_footabll_wages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Wages_cost = pd.read_html('https://www.spotrac.com/epl/payroll/')
Wages_cost[0]
# Out:
#     Rank                          Team  Active Players     Forwards  \
# 0      1        Manchester United F.C.              29  £84,170,000
# 1      2                  Chelsea F.C.              27  £22,464,000
# 2      3          Manchester City F.C.              24  £22,100,000
# 3      4                Liverpool F.C.              28  £51,242,000
# 4      5        Tottenham Hotspur F.C.              25  £39,104,000
# 5      6                  Arsenal F.C.              25  £22,360,000
# 6      7              Aston Villa F.C.              26  £20,560,000
# 7      8                Leicester City              26  £15,970,000
# 8      9          West Ham United F.C.              28  £10,880,000
# 9     10         Newcastle United F.C.              30  £21,473,600
# 10    11                Crystal Palace              24  £16,155,000
# 11    12                  Everton F.C.              28   £7,975,000
# 12    13  Wolverhampton Wanderers F.C.              31  £16,510,000
# ...

# %%
df = Wages_cost[0]
df.head(5)
# Out:
#    Rank                    Team  Active Players     Forwards  Midfielders  \
# 0     1  Manchester United F.C.              29  £84,170,000  £51,480,000
# 1     2            Chelsea F.C.              27  £22,464,000  £86,080,000
# 2     3    Manchester City F.C.              24  £22,100,000  £89,360,000
# 3     4          Liverpool F.C.              28  £51,242,000  £47,970,000
# 4     5  Tottenham Hotspur F.C.              25  £39,104,000  £29,905,200
#
#     Defensemen  Goalkeepers Transfer Fees Est. Total Salary
# 0  £67,775,000  £23,656,000  £261,830,000      £227,081,000
# 1  £63,180,000  £12,324,000  £313,280,000      £189,048,000
# 2  £58,880,000   £7,540,000  £153,170,000      £177,880,000
# 3  £46,000,000  £11,128,000   £94,370,000      £156,340,000
# 4  £29,450,000   £9,180,000  £167,090,000      £107,639,200

# %%
df_simplified = df.drop(['Rank', 'Active Players', 'Forwards','Midfielders', 'Defensemen', 'Goalkeepers', 'Transfer Fees'], axis=1)
df_simplified.rename(columns = {'Est. Total Salary':'Estimated Total Salary'}, inplace = True)

# %%
df_top16 = df_simplified.iloc[:16]
df_top16['Estimated Total Salary'] = df_top16['Estimated Total Salary'].str.replace(',', '').str.replace('£', '')

print(df_top16)
# Out:
#                             Team Estimated Total Salary
# 0         Manchester United F.C.              227081000
# 1                   Chelsea F.C.              189048000
# 2           Manchester City F.C.              177880000
# 3                 Liverpool F.C.              156340000
# 4         Tottenham Hotspur F.C.              107639200
# 5                   Arsenal F.C.               95200000
# 6               Aston Villa F.C.               81387396
# 7                 Leicester City               69473000
# 8           West Ham United F.C.               68486000
# 9          Newcastle United F.C.               65764200
# 10                Crystal Palace               59425000
# 11                  Everton F.C.               45883000
# 12  Wolverhampton Wanderers F.C.               41116000
# 13                   Fulham F.C.               37636824
# 14              Southampton F.C.               36224000
# 15        Brighton & Hove Albion               29981333
# ...

# %%
exported_values = list(df_top16.T.to_dict().values())

# %%
import json
open('Total_wage_cost_football_data.json' , 'w').write( json.dumps(exported_values) )
# Out:
# 1113
